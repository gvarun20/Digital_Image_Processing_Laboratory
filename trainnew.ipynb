# %%
from keras.models import Sequential
from keras.layers import Conv2D
from keras.layers import MaxPooling2D
from keras.layers import Flatten
from keras.layers import Dense
from keras.preprocessing.image import ImageDataGenerator


model = Sequential()
model.add(Conv2D(32, (3, 3), input_shape = (64, 64, 3), activation = 'relu'))
model.add(MaxPooling2D(pool_size = (2, 2)))
model.add(Flatten())
model.add(Dense(units = 128, activation = 'relu'))
model.add(Dense(units = 1, activation = 'sigmoid'))

model.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

train_datagen = ImageDataGenerator(rescale = 1./255,
                                   shear_range = 0.2,
                                   zoom_range = 0.2,
                                   horizontal_flip = True)
val_datagen = ImageDataGenerator(rescale = 1./255)

training_set = train_datagen.flow_from_directory('Dataset/train',
                                                 target_size = (64, 64),
                                                 batch_size = 8,
                                                 class_mode = 'binary')
val_set = val_datagen.flow_from_directory('Dataset/val',
                                            target_size = (64, 64),
                                            batch_size = 8,
                                            class_mode = 'binary')

model.fit_generator(training_set,
                         steps_per_epoch = 50,
                         epochs = 50,
                         validation_data = val_set,
                         validation_steps = 2)



model_json = model.to_json()
with open("model.json", "w") as json_file:
    json_file.write(model_json)
model.save_weights("model.h5")
print("Saved model to disk")
# Out:
# Found 4035 images belonging to 2 classes.
# Found 65 images belonging to 2 classes.
# Epoch 1/50
# C:\Users\HI\AppData\Local\Temp\ipykernel_4160\338747781.py:33: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   model.fit_generator(training_set,
# 50/50 [==============================] - 7s 111ms/step - loss: 0.7927 - accuracy: 0.5950 - val_loss: 0.6344 - val_accuracy: 0.5625
# Epoch 2/50
# 50/50 [==============================] - 5s 100ms/step - loss: 0.4722 - accuracy: 0.8100 - val_loss: 0.7977 - val_accuracy: 0.5625
# Epoch 3/50
# 50/50 [==============================] - 5s 96ms/step - loss: 0.4516 - accuracy: 0.8050 - val_loss: 0.3743 - val_accuracy: 0.9375
# Epoch 4/50
# 50/50 [==============================] - 5s 102ms/step - loss: 0.3352 - accuracy: 0.8850 - val_loss: 0.8898 - val_accuracy: 0.7500
# Epoch 5/50
# 50/50 [==============================] - 5s 101ms/step - loss: 0.3334 - accuracy: 0.8625 - val_loss: 0.2772 - val_accuracy: 0.9375
# Epoch 6/50
# 50/50 [==============================] - 5s 98ms/step - loss: 0.2574 - accuracy: 0.8950 - val_loss: 0.4264 - val_accuracy: 0.7500
# Epoch 7/50
# 50/50 [==============================] - 5s 104ms/step - loss: 0.2725 - accuracy: 0.8725 - val_loss: 0.2300 - val_accuracy: 0.8750
# Epoch 8/50
# 50/50 [==============================] - 5s 102ms/step - loss: 0.3450 - accuracy: 0.8525 - val_loss: 0.5355 - val_accuracy: 0.6875
# Epoch 9/50
# 50/50 [==============================] - 5s 105ms/step - loss: 0.3042 - accuracy: 0.8900 - val_loss: 0.3252 - val_accuracy: 0.8750
# Epoch 10/50
# 50/50 [==============================] - 5s 108ms/step - loss: 0.2438 - accuracy: 0.9025 - val_loss: 0.4144 - val_accuracy: 0.7500
# Epoch 11/50
# 50/50 [==============================] - 6s 111ms/step - loss: 0.2216 - accuracy: 0.9125 - val_loss: 0.1388 - val_accuracy: 0.9375
# Epoch 12/50
# 50/50 [==============================] - 5s 104ms/step - loss: 0.2248 - accuracy: 0.9050 - val_loss: 0.0299 - val_accuracy: 1.0000
# Epoch 13/50
# 50/50 [==============================] - 5s 98ms/step - loss: 0.2353 - accuracy: 0.9000 - val_loss: 0.2162 - val_accuracy: 0.8750
# Epoch 14/50
# 50/50 [==============================] - 5s 98ms/step - loss: 0.3969 - accuracy: 0.8304 - val_loss: 0.5815 - val_accuracy: 0.6875
# Epoch 15/50
# 50/50 [==============================] - 5s 99ms/step - loss: 0.2768 - accuracy: 0.8900 - val_loss: 0.2961 - val_accuracy: 0.8125
# Epoch 16/50
# 50/50 [==============================] - 5s 97ms/step - loss: 0.2602 - accuracy: 0.8975 - val_loss: 0.3989 - val_accuracy: 0.8125
# Epoch 17/50
# 50/50 [==============================] - 5s 107ms/step - loss: 0.2599 - accuracy: 0.9000 - val_loss: 0.1738 - val_accuracy: 0.9375
# Epoch 18/50
# 50/50 [==============================] - 6s 116ms/step - loss: 0.2144 - accuracy: 0.9200 - val_loss: 0.3419 - val_accuracy: 0.8125
# Epoch 19/50
# 50/50 [==============================] - 5s 102ms/step - loss: 0.2054 - accuracy: 0.9150 - val_loss: 0.1601 - val_accuracy: 0.8750
# Epoch 20/50
# 50/50 [==============================] - 5s 105ms/step - loss: 0.2110 - accuracy: 0.9200 - val_loss: 0.4424 - val_accuracy: 0.8750
# Epoch 21/50
# 50/50 [==============================] - 5s 103ms/step - loss: 0.1629 - accuracy: 0.9325 - val_loss: 0.2651 - val_accuracy: 0.9375
# Epoch 22/50
# 50/50 [==============================] - 5s 100ms/step - loss: 0.2466 - accuracy: 0.9125 - val_loss: 0.1685 - val_accuracy: 0.9375
# Epoch 23/50
# 50/50 [==============================] - 5s 99ms/step - loss: 0.1694 - accuracy: 0.9400 - val_loss: 0.0949 - val_accuracy: 0.9375
# Epoch 24/50
# 50/50 [==============================] - 5s 96ms/step - loss: 0.2199 - accuracy: 0.9075 - val_loss: 0.1441 - val_accuracy: 0.9375
# Epoch 25/50
# 50/50 [==============================] - 6s 112ms/step - loss: 0.1522 - accuracy: 0.9494 - val_loss: 0.2490 - val_accuracy: 0.9375
# Epoch 26/50
# 50/50 [==============================] - 6s 114ms/step - loss: 0.1933 - accuracy: 0.9150 - val_loss: 0.2998 - val_accuracy: 0.8750
# Epoch 27/50
# 50/50 [==============================] - 5s 106ms/step - loss: 0.2350 - accuracy: 0.8962 - val_loss: 0.0980 - val_accuracy: 1.0000
# Epoch 28/50
# 50/50 [==============================] - 5s 96ms/step - loss: 0.2490 - accuracy: 0.9000 - val_loss: 0.2218 - val_accuracy: 0.9375
# Epoch 29/50
# 50/50 [==============================] - 5s 98ms/step - loss: 0.1805 - accuracy: 0.9375 - val_loss: 0.4553 - val_accuracy: 0.8750
# Epoch 30/50
# 50/50 [==============================] - 5s 103ms/step - loss: 0.1580 - accuracy: 0.9375 - val_loss: 0.1831 - val_accuracy: 0.8750
# Epoch 31/50
# 50/50 [==============================] - 5s 106ms/step - loss: 0.2181 - accuracy: 0.9050 - val_loss: 0.0958 - val_accuracy: 0.9375
# Epoch 32/50
# 50/50 [==============================] - 5s 104ms/step - loss: 0.1497 - accuracy: 0.9400 - val_loss: 0.1214 - val_accuracy: 0.9375
# Epoch 33/50
# 50/50 [==============================] - 5s 109ms/step - loss: 0.2357 - accuracy: 0.8900 - val_loss: 0.1734 - val_accuracy: 0.8750
# Epoch 34/50
# 50/50 [==============================] - 5s 99ms/step - loss: 0.2217 - accuracy: 0.9150 - val_loss: 0.0724 - val_accuracy: 1.0000
# Epoch 35/50
# 50/50 [==============================] - 5s 99ms/step - loss: 0.1720 - accuracy: 0.9350 - val_loss: 0.8627 - val_accuracy: 0.7500
# Epoch 36/50
# 50/50 [==============================] - 5s 97ms/step - loss: 0.2025 - accuracy: 0.8975 - val_loss: 0.3756 - val_accuracy: 0.7500
# Epoch 37/50
# 50/50 [==============================] - 5s 98ms/step - loss: 0.1692 - accuracy: 0.9275 - val_loss: 0.0991 - val_accuracy: 0.9375
# Epoch 38/50
# 50/50 [==============================] - 5s 99ms/step - loss: 0.1565 - accuracy: 0.9375 - val_loss: 0.0240 - val_accuracy: 1.0000
# Epoch 39/50
# 50/50 [==============================] - 5s 99ms/step - loss: 0.1596 - accuracy: 0.9450 - val_loss: 0.1227 - val_accuracy: 0.9375
# Epoch 40/50
# 50/50 [==============================] - 5s 99ms/step - loss: 0.1578 - accuracy: 0.9325 - val_loss: 0.1748 - val_accuracy: 0.8750
# Epoch 41/50
# 50/50 [==============================] - 5s 102ms/step - loss: 0.2125 - accuracy: 0.9000 - val_loss: 0.0939 - val_accuracy: 0.9375
# Epoch 42/50
# 50/50 [==============================] - 5s 105ms/step - loss: 0.1654 - accuracy: 0.9350 - val_loss: 0.1316 - val_accuracy: 0.9375
# Epoch 43/50
# 50/50 [==============================] - 5s 103ms/step - loss: 0.1639 - accuracy: 0.9225 - val_loss: 0.2141 - val_accuracy: 0.8750
# Epoch 44/50
# 50/50 [==============================] - 5s 108ms/step - loss: 0.1813 - accuracy: 0.9300 - val_loss: 0.0970 - val_accuracy: 0.9375
# Epoch 45/50
# 50/50 [==============================] - 5s 101ms/step - loss: 0.1350 - accuracy: 0.9500 - val_loss: 0.2524 - val_accuracy: 0.8750
# Epoch 46/50
# 50/50 [==============================] - 5s 100ms/step - loss: 0.1341 - accuracy: 0.9494 - val_loss: 0.0327 - val_accuracy: 1.0000
# Epoch 47/50
# 50/50 [==============================] - 5s 101ms/step - loss: 0.1122 - accuracy: 0.9575 - val_loss: 0.0491 - val_accuracy: 1.0000
# Epoch 48/50
# 50/50 [==============================] - 5s 97ms/step - loss: 0.1588 - accuracy: 0.9325 - val_loss: 0.1382 - val_accuracy: 0.9375
# Epoch 49/50
# 50/50 [==============================] - 5s 98ms/step - loss: 0.1545 - accuracy: 0.9225 - val_loss: 0.2690 - val_accuracy: 0.8125
# Epoch 50/50
# 50/50 [==============================] - 5s 100ms/step - loss: 0.1734 - accuracy: 0.9175 - val_loss: 0.4172 - val_accuracy: 0.8125
# Saved model to disk
